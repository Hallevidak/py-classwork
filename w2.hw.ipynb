# %%
name = "Halle"
print("string:", str("Halle"))

age = 21
print("integer:", int(21))

grade = 16.0
print("float:", grade)

is_student = True
print("boolean:", is_student)

favorite_color = "blue"
print("string:", favorite_color)
# Out:
# string: Halle
# integer: 21
# float: 16.0
# boolean: True
# string: blue

# %%
name = "Halle" #string 
age = 21 #integer
grade = 16.0 #float 
is_student = True #boolean
favorite_color = "blue" #string

# %%
name = "HALLE"
print("string:", name)
# Out:
# string: HALLE

# %%
print("age_grade:", int(age) + grade)
# Out:
# age_grade: 37.0

# %%
person = {'name': 'Halle','age': 21, 'grade': 16.0, 'is_student': True, 'favorite_color': 'blue'}
print("dictionary:", person)
# Out:
# dictionary: {'name': 'Halle', 'age': 21, 'grade': 16.0, 'is_student': True, 'favorite_color': 'blue'}

# %%
f'My name is {name}, I am {age} years old. My favorite color is {favorite_color}. I will get a {grade} in this class.'
# Out:
# 'My name is HALLE, I am 21 years old. My favorite color is blue. I will get a 16.0 in this class.'
