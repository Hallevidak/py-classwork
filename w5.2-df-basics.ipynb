# %%
#.iloc, .at, .iat
# pull in data and play 

import pandas as pd

url = "https://raw.githubusercontent.com/nkmwicz/data-for-students/refs/heads/main/french-ambs.csv"
df = pd.read_csv(url)
df.head(10)
# Out:
#    id                      name    place  year    lat   long      lat_long
# 0   0        Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1        Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2        Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57
# 3   3        Danzay, Charles de  Denmark  1563  55.68  12.57  55.68, 12.57
# 4   4        Danzay, Charles de  Denmark  1582  55.68  12.57  55.68, 12.57
# 5   5        Bapaume, Robert de  England  1516  51.51  -0.12  51.51, -0.12
# 6   6  Passano, Jean-Joachim de  England  1527  51.51  -0.12  51.51, -0.12
# 7   7               De Monpreat  England  1532  51.51  -0.12  51.51, -0.12
# 8   8           Du Bellay, Jean  England  1530  51.51  -0.12  51.51, -0.12
# 9   9     Castelnau, Antoine de  England  1534  51.51  -0.12  51.51, -0.12

# %%
# file paths 
# absolute file pass
#c/Users/michalewiczn/Document/python-class/
# relative file pass 
#./ (where we are)
#../ (go up one folder)
#../../../
#./data/

# %%
df.to_csv("./data/french-ambs.csv", index=False)

# %%
df = pd.read_csv("./data/french-ambs.csv")
df.head()
# Out:
#    id                name    place  year    lat   long      lat_long
# 0   0  Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1  Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2  Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57
# 3   3  Danzay, Charles de  Denmark  1563  55.68  12.57  55.68, 12.57
# 4   4  Danzay, Charles de  Denmark  1582  55.68  12.57  55.68, 12.57

# %%
#located within data set 
df.loc[df["place"] == "England", "name"]
# Out:
# 5            Bapaume, Robert de
# 6      Passano, Jean-Joachim de
# 7                   De Monpreat
# 8               Du Bellay, Jean
# 9         Castelnau, Antoine de
#                  ...
# 817     La Pommeraie, Gilles de
# 818                   Pot, Jean
# 819              De Selve, Odet
# 820             La Fin, Jean de
# 821    L'Aubspine, Guillaume de
# Name: name, Length: 93, dtype: object

# %%
# finds locations by index 
df.iloc[0, 1]
# Out:
# 'Richer, Christophe'

# %%
df.iloc[72]
# Out:
# id                                           72
# name        Rougier, François, Baron of Ferrals
# place                               Netherlands
# year                                       1568
# lat                                       52.37
# long                                       4.89
# lat_long                            52.37, 4.89
# Name: 72, dtype: object

# %%
for i in range(10):
    print(df.iloc[i])
# Out:
# id                           0
# name        Richer, Christophe
# place                  Denmark
# year                      1543
# lat                      55.68
# long                     12.57
# lat_long          55.68, 12.57
# Name: 0, dtype: object
# id                           1
# name        Richer, Christophe
# place                  Denmark
# year                      1541
# lat                      55.68
# long                     12.57
# lat_long          55.68, 12.57
# Name: 1, dtype: object
# id                           2
# name        Danzay, Charles de
# place                  Denmark
# year                      1561
# lat                      55.68
# long                     12.57
# lat_long          55.68, 12.57
# Name: 2, dtype: object
# id                           3
# name        Danzay, Charles de
# place                  Denmark
# year                      1563
# lat                      55.68
# long                     12.57
# lat_long          55.68, 12.57
# ...

# %%
df.iloc[0,0] = 0

# %%
df.iloc[0:3]
# Out:
#    id                name    place  year    lat   long      lat_long
# 0   0  Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1  Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2  Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57

# %%
#.at[], .iat[]
# The same as .loc and .iloc, but only used for individual cells
df.at[0, "place"] #index and then label, indexes are numbers right now, hence 0
# Out:
# 'Denmark'

# %%
df.iat[0,3] #the index and then the 3rd row 
# df.iat[0,3] = 1546 #changes that cell

# %%
# ITERATING 
df.columns
# Out:
# Index(['id', 'name', 'place', 'year', 'lat', 'long', 'lat_long'], dtype='object')

# %%
for col in df.columns:
    print (col, pd.api.types.is_numeric_dtype(df[col]))
# Out:
# id True
# name False
# place False
# year True
# lat True
# long True
# lat_long False

# %%
# loop over rows 
# iterrows returns a list \
# Let's rename anywhere is says "Denmark" to "Den."
for idx, item in df.iterrows():
    print(item['place'])
# Out:
# Denmark
# Denmark
# Denmark
# Denmark
# Denmark
# England
# England
# England
# England
# England
# England
# England
# England
# England
# England
# Geneva
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Portugal
# Portugal
# Portugal
# Rome
# Rome
# Rome
# Rome
# Scotland
# Spain
# Spain
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Venice
# Venice
# Venice
# Venice
# Venice
# Denmark
# Denmark
# Denmark
# Denmark
# England
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Netherlands
# Netherlands
# Netherlands
# Ottoman Empire
# Ottoman Empire
# ...

# %%
#itertuples() is faster 

for item in df.itertuples():
    print(item.name) #named tuples use dot notation
# Out:
# Richer, Christophe
# Richer, Christophe
# Danzay, Charles de
# Danzay, Charles de
# Danzay, Charles de
# Bapaume, Robert de
# Passano, Jean-Joachim de
# De Monpreat
# Du Bellay, Jean
# Castelnau, Antoine de
# De Selve, Odet
# Castelneau, Michel de
# Castelneau, Michel de
# La Fin, Jean de
# La Mothe-Fénélon, Bertrand de Salignac de
# Boistaillé, Jean Hurault de
# Castion, Jean-Jacques de
# Monstiers, Jean de
# Salazar, Louis de
# Gredio, Christian
# Crassier, Bernard de
# Grangier, Jean
# Florin, Jean
# Bochetel, Bernardin
# Vulcob, Jean de, sr. de Sassy
# Vulcob, Jean de, sr. de Sassy
# Choary, Paul
# d'Aramon, Gabriel Leutz
# La Triquerie, Pierre de
# La Triquerie, Pierre de
# Berthier, Sébastien
# De Brèves, François Savary
# De Caix, Honoré
# De Caix, Honoré
# Nicot, Jean
# De Selve, Georges
# Langeac, Jean de
# De Selve, Jean-Paul
# Vivonne, Jean de
# Clutin, Henri
# d'Ebrard de Saint Sulpice, Jean
# Fourquevaux, Raymond de Beccarie de Pavie, Baron of
# Daugerant, Louis
# ...

# %%
for idx, id, n, p, y, lat, long, _ in df.itertuples():
    print(p)
# Out:
# Denmark
# Denmark
# Denmark
# Denmark
# Denmark
# England
# England
# England
# England
# England
# England
# England
# England
# England
# England
# Geneva
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Portugal
# Portugal
# Portugal
# Rome
# Rome
# Rome
# Rome
# Scotland
# Spain
# Spain
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Venice
# Venice
# Venice
# Venice
# Venice
# Denmark
# Denmark
# Denmark
# Denmark
# England
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Netherlands
# Netherlands
# Netherlands
# Ottoman Empire
# Ottoman Empire
# ...

# %%
for item in df.itertuples():
    if item.place == 'Denmark':
        df.at[item.Index, 'place'] = 'Den.'
df['place'].unique() #get unique calues existing in column
# Out:
# array(['Den.', 'England', 'Geneva', 'Grisons', 'Holy Roman Empire',
#        'Netherlands', 'Ottoman Empire', 'Portugal', 'Rome', 'Scotland',
#        'Spain', 'Swiss Cantons', 'Venice', 'Poland', 'Savoy', 'Ferrara',
#        'Saxony', 'Tuscany'], dtype=object)

# %%
# England to Eng. 
# if only changing one name, use .loc
df.loc[df["place"] == "England", "place"] = "Eng."
df["place"].unique()
# Out:
# array(['Den.', 'Eng.', 'Geneva', 'Grisons', 'Holy Roman Empire',
#        'Netherlands', 'Ottoman Empire', 'Portugal', 'Rome', 'Scotland',
#        'Spain', 'Swiss Cantons', 'Venice', 'Poland', 'Savoy', 'Ferrara',
#        'Saxony', 'Tuscany'], dtype=object)

# %%
#.replace() for multiple 
#hash = {
#    "Holy Roman Empire": "HRE",
#   "Geneva": "Gen."
#}

# hash map is a 

hash = {name:f"{name[:3]}." for name in df['place'].unique() if len(name) != 4}
hash

#PANDAS OPERATORS & (AND), | (OR), ~ (NOT)
df.loc[(df["place"] == "Den.") & (df['year'] < 1561) & (df['year'] > 1550)].count()
# Out:
# id          4
# name        4
# place       4
# year        4
# lat         4
# long        4
# lat_long    4
# dtype: int64

# %%
# use ~
df.loc[~(df["place"] == "Den.") & (df['year'] < 1561) & (df['year'] > 1550)].count()
# Out:
# id          117
# name        117
# place       117
# year        117
# lat         117
# long        117
# lat_long    117
# dtype: int64

# %%
imp_ambs = ['Eng.', 'Ott.', 'Ven.']
df.loc[(df['place'].isin(imp_ambs)) & (df['year']< 1561) & (df['year'] > 1550)].count()
# Out:
# id          14
# name        14
# place       14
# year        14
# lat         14
# long        14
# lat_long    14
# dtype: int64

# %%
for item in df['place'].unique():
    if item in imp_ambs:
        print(f"is {item} in ambs list? {item in imp_ambs}")
# Out:
# is Eng. in ambs list? True
